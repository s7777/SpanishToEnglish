# %%
import string
import re
from pickle import dump
from unicodedata import normalize
from numpy import array

# load doc into memory
def load_doc(filename):
	# open the file as read only
	file = open(filename, mode='rt', encoding='utf-8')
	# read all text
	text = file.read()
	# close the file
	file.close()
	return text

# split a loaded document into sentences
def to_pairs(doc):
	lines = doc.strip().split('\n')
	pairs = [line.split('\t') for line in  lines]
	return pairs

# clean a list of lines
def clean_pairs(lines):
	cleaned = list()
	# prepare regex for char filtering
	re_print = re.compile('[^%s]' % re.escape(string.printable))
	# prepare translation table for removing punctuation
	table = str.maketrans('', '', string.punctuation)
	for pair in lines:
		clean_pair = list()
		for line in pair:
			# normalize unicode characters
			line = normalize('NFD', line).encode('ascii', 'ignore')
			line = line.decode('UTF-8')
			# tokenize on white space
			line = line.split()
			# convert to lowercase
			line = [word.lower() for word in line]
			# remove punctuation from each token
			line = [word.translate(table) for word in line]
			# remove non-printable chars form each token
			line = [re_print.sub('', w) for w in line]
			# remove tokens with numbers in them
			line = [word for word in line if word.isalpha()]
			# store as string
			clean_pair.append(' '.join(line))
		cleaned.append(clean_pair)
	return array(cleaned)

# save a list of clean sentences to file
def save_clean_data(sentences, filename):
	dump(sentences, open(filename, 'wb'))
	print('Saved: %s' % filename)

# load dataset
filename = 'spa.txt'
doc = load_doc(filename)
# split into english-german pairs
pairs = to_pairs(doc)
# clean sentences
clean_pairs = clean_pairs(pairs)
# save clean pairs to file
save_clean_data(clean_pairs, 'english-spanish.pkl')
# spot check
for i in range(100):
	print('[%s] => [%s]' % (clean_pairs[i,0], clean_pairs[i,1]))
# Out:
# Saved: english-spanish.pkl
# [go] => [ve]
# [go] => [vete]
# [go] => [vaya]
# [go] => [vayase]
# [hi] => [hola]
# [run] => [corre]
# [run] => [corran]
# [run] => [corra]
# [run] => [corred]
# [run] => [corred]
# [who] => [quien]
# [wow] => [orale]
# [fire] => [fuego]
# [fire] => [incendio]
# [fire] => [disparad]
# [help] => [ayuda]
# [help] => [socorro auxilio]
# [help] => [auxilio]
# [jump] => [salta]
# [jump] => [salte]
# [stop] => [parad]
# [stop] => [para]
# [stop] => [pare]
# [wait] => [espera]
# [wait] => [esperen]
# [go on] => [continua]
# [go on] => [continue]
# [hello] => [hola]
# [hurry] => [date prisa]
# [hurry] => [daos prisa]
# [hurry] => [dese prisa]
# [i hid] => [me oculte]
# [i hid] => [me escondi]
# [i hid] => [me ocultaba]
# [i hid] => [me escondia]
# [i ran] => [corri]
# [i ran] => [corria]
# [i try] => [lo intento]
# [i won] => [he ganado]
# [oh no] => [oh no]
# [relax] => [tomatelo con soda]
# [shoot] => [fuego]
# [shoot] => [disparad]
# [shoot] => [disparen]
# [shoot] => [dispara]
# [shoot] => [dispara]
# [shoot] => [dispare]
# [smile] => [sonrie]
# [attack] => [al ataque]
# [attack] => [atacad]
# [attack] => [ataque]
# [attack] => [ataquen]
# [attack] => [ataca]
# [get up] => [levanta]
# [go now] => [ve ahora mismo]
# [go now] => [id ahora mismo]
# [go now] => [vaya ahora mismo]
# [go now] => [vayan ahora mismo]
# [go now] => [ve ya]
# [go now] => [id ya]
# [go now] => [vaya ya]
# [go now] => [vayan ya]
# [got it] => [lo tengo]
# [got it] => [lo pillas]
# [got it] => [entendiste]
# [he ran] => [el corrio]
# [hop in] => [metete adentro]
# [hug me] => [abrazame]
# [i care] => [me preocupo]
# [i fell] => [me cai]
# [i fled] => [hui]
# [i fled] => [me escape]
# [i fled] => [huia]
# [i fled] => [me escapaba]
# [i know] => [yo lo se]
# [i left] => [sali]
# [i lied] => [menti]
# [i lost] => [perdi]
# [i quit] => [dimito]
# [i quit] => [renuncie]
# [i quit] => [lo dejo]
# [i sang] => [cante]
# [i wept] => [llore]
# [i wept] => [lloraba]
# [i work] => [estoy trabajando]
# [im] => [tengo diecinueve]
# [im up] => [estoy levantado]
# [listen] => [escucha]
# [listen] => [escuche]
# [listen] => [escuchen]
# [no way] => [no puede ser]
# [no way] => [de ninguna manera]
# [no way] => [de ninguna manera]
# [no way] => [imposible]
# [no way] => [de ningun modo]
# [no way] => [de eso nada]
# [no way] => [ni cagando]
# [no way] => [mangos]
# [no way] => [minga]
# [no way] => [ni en pedo]

# %%
from pickle import load
from pickle import dump
from numpy.random import rand
from numpy.random import shuffle

# load a clean dataset
def load_clean_sentences(filename):
	return load(open(filename, 'rb'))

# save a list of clean sentences to file
def save_clean_data(sentences, filename):
	dump(sentences, open(filename, 'wb'))
	print('Saved: %s' % filename)

# load dataset
raw_dataset = load_clean_sentences('english-spanish.pkl')

# reduce dataset size
n_sentences = 10000
dataset = raw_dataset[:n_sentences, :]
# random shuffle
shuffle(dataset)
# split into train/test
train, test = dataset[:9000], dataset[1000:]
# save
save_clean_data(dataset, 'english-spanish-both.pkl')
save_clean_data(train, 'english-spanish-train.pkl')
save_clean_data(test, 'english-spanish-test.pkl')
# Out:
# Saved: english-spanish-both.pkl
# Saved: english-spanish-train.pkl
# Saved: english-spanish-test.pkl

# %%
from pickle import load
from numpy import array
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from keras.utils.vis_utils import plot_model
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import Embedding
from keras.layers import RepeatVector
from keras.layers import TimeDistributed
from keras.callbacks import ModelCheckpoint

# load a clean dataset
def load_clean_sentences(filename):
	return load(open(filename, 'rb'))

# fit a tokenizer
def create_tokenizer(lines):
	tokenizer = Tokenizer()
	tokenizer.fit_on_texts(lines)
	return tokenizer

# max sentence length
def max_length(lines):
	return max(len(line.split()) for line in lines)

# encode and pad sequences
def encode_sequences(tokenizer, length, lines):
	# integer encode sequences
	X = tokenizer.texts_to_sequences(lines)
	# pad sequences with 0 values
	X = pad_sequences(X, maxlen=length, padding='post')
	return X

# one hot encode target sequence
def encode_output(sequences, vocab_size):
	ylist = list()
	for sequence in sequences:
		encoded = to_categorical(sequence, num_classes=vocab_size)
		ylist.append(encoded)
	y = array(ylist)
	y = y.reshape(sequences.shape[0], sequences.shape[1], vocab_size)
	return y

# define NMT model
def define_model(src_vocab, tar_vocab, src_timesteps, tar_timesteps, n_units):
	model = Sequential()
	model.add(Embedding(src_vocab, n_units, input_length=src_timesteps, mask_zero=True))
	model.add(LSTM(n_units))
	model.add(RepeatVector(tar_timesteps))
	model.add(LSTM(n_units, return_sequences=True))
	model.add(TimeDistributed(Dense(tar_vocab, activation='softmax')))
	return model

# load datasets
dataset = load_clean_sentences('english-spanish-both.pkl')
train = load_clean_sentences('english-spanish-train.pkl')
test = load_clean_sentences('english-spanish-test.pkl')

# prepare english tokenizer
eng_tokenizer = create_tokenizer(dataset[:, 0])
eng_vocab_size = len(eng_tokenizer.word_index) + 1
eng_length = max_length(dataset[:, 0])
print('English Vocabulary Size: %d' % eng_vocab_size)
print('English Max Length: %d' % (eng_length))
# prepare german tokenizer
ger_tokenizer = create_tokenizer(dataset[:, 1])
ger_vocab_size = len(ger_tokenizer.word_index) + 1
ger_length = max_length(dataset[:, 1])
print('Spanish Vocabulary Size: %d' % ger_vocab_size)
print('Spanish Max Length: %d' % (ger_length))

# prepare training data
trainX = encode_sequences(ger_tokenizer, ger_length, train[:, 1])
trainY = encode_sequences(eng_tokenizer, eng_length, train[:, 0])
trainY = encode_output(trainY, eng_vocab_size)
# prepare validation data
testX = encode_sequences(ger_tokenizer, ger_length, test[:, 1])
testY = encode_sequences(eng_tokenizer, eng_length, test[:, 0])
testY = encode_output(testY, eng_vocab_size)

# define model
model = define_model(ger_vocab_size, eng_vocab_size, ger_length, eng_length, 256)
model.compile(optimizer='adam', loss='categorical_crossentropy')
# summarize defined model
print(model.summary())
plot_model(model, to_file='model.png', show_shapes=True)
# fit model
filename = 'model.h5'
checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
model.fit(trainX, trainY, epochs=100, batch_size=64, validation_data=(testX, testY), callbacks=[checkpoint], verbose=2)
# Out:
# English Vocabulary Size: 2335
# English Max Length: 5
# Spanish Vocabulary Size: 4552
# Spanish Max Length: 8
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 8, 256)            1165312
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 256)               525312
# _________________________________________________________________
# repeat_vector_1 (RepeatVecto (None, 5, 256)            0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 5, 256)            525312
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 5, 2335)           600095
# =================================================================
# Total params: 2,816,031
# Trainable params: 2,816,031
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 141/141 - 33s - loss: 4.4169 - val_loss: 3.5219
#
# Epoch 00001: val_loss improved from inf to 3.52190, saving model to model.h5
# Epoch 2/100
# 141/141 - 27s - loss: 3.4307 - val_loss: 3.3101
#
# Epoch 00002: val_loss improved from 3.52190 to 3.31006, saving model to model.h5
# Epoch 3/100
# 141/141 - 28s - loss: 3.2749 - val_loss: 3.1847
#
# Epoch 00003: val_loss improved from 3.31006 to 3.18472, saving model to model.h5
# Epoch 4/100
# 141/141 - 27s - loss: 3.1584 - val_loss: 3.0943
#
# Epoch 00004: val_loss improved from 3.18472 to 3.09426, saving model to model.h5
# Epoch 5/100
# 141/141 - 27s - loss: 3.0545 - val_loss: 2.9734
#
# Epoch 00005: val_loss improved from 3.09426 to 2.97344, saving model to model.h5
# Epoch 6/100
# 141/141 - 27s - loss: 2.9142 - val_loss: 2.8182
#
# Epoch 00006: val_loss improved from 2.97344 to 2.81820, saving model to model.h5
# Epoch 7/100
# 141/141 - 27s - loss: 2.7648 - val_loss: 2.6933
#
# Epoch 00007: val_loss improved from 2.81820 to 2.69332, saving model to model.h5
# Epoch 8/100
# 141/141 - 27s - loss: 2.6353 - val_loss: 2.5564
#
# Epoch 00008: val_loss improved from 2.69332 to 2.55641, saving model to model.h5
# Epoch 9/100
# 141/141 - 27s - loss: 2.5024 - val_loss: 2.4316
#
# Epoch 00009: val_loss improved from 2.55641 to 2.43157, saving model to model.h5
# Epoch 10/100
# 141/141 - 27s - loss: 2.3732 - val_loss: 2.3050
#
# Epoch 00010: val_loss improved from 2.43157 to 2.30499, saving model to model.h5
# Epoch 11/100
# 141/141 - 27s - loss: 2.2487 - val_loss: 2.1880
#
# Epoch 00011: val_loss improved from 2.30499 to 2.18797, saving model to model.h5
# Epoch 12/100
# 141/141 - 27s - loss: 2.1301 - val_loss: 2.0823
#
# Epoch 00012: val_loss improved from 2.18797 to 2.08225, saving model to model.h5
# Epoch 13/100
# 141/141 - 27s - loss: 2.0150 - val_loss: 1.9681
#
# Epoch 00013: val_loss improved from 2.08225 to 1.96811, saving model to model.h5
# Epoch 14/100
# 141/141 - 27s - loss: 1.8994 - val_loss: 1.8574
#
# Epoch 00014: val_loss improved from 1.96811 to 1.85740, saving model to model.h5
# Epoch 15/100
# 141/141 - 27s - loss: 1.7870 - val_loss: 1.7495
#
# Epoch 00015: val_loss improved from 1.85740 to 1.74947, saving model to model.h5
# Epoch 16/100
# 141/141 - 27s - loss: 1.6765 - val_loss: 1.6541
#
# Epoch 00016: val_loss improved from 1.74947 to 1.65410, saving model to model.h5
# Epoch 17/100
# 141/141 - 28s - loss: 1.5707 - val_loss: 1.5502
#
# Epoch 00017: val_loss improved from 1.65410 to 1.55017, saving model to model.h5
# Epoch 18/100
# 141/141 - 27s - loss: 1.4670 - val_loss: 1.4621
#
# Epoch 00018: val_loss improved from 1.55017 to 1.46213, saving model to model.h5
# Epoch 19/100
# 141/141 - 27s - loss: 1.3721 - val_loss: 1.3741
#
# Epoch 00019: val_loss improved from 1.46213 to 1.37415, saving model to model.h5
# Epoch 20/100
# 141/141 - 27s - loss: 1.2773 - val_loss: 1.2985
#
# Epoch 00020: val_loss improved from 1.37415 to 1.29847, saving model to model.h5
# Epoch 21/100
# 141/141 - 29s - loss: 1.1937 - val_loss: 1.2206
#
# Epoch 00021: val_loss improved from 1.29847 to 1.22060, saving model to model.h5
# Epoch 22/100
# 141/141 - 27s - loss: 1.1087 - val_loss: 1.1535
#
# Epoch 00022: val_loss improved from 1.22060 to 1.15350, saving model to model.h5
# Epoch 23/100
# 141/141 - 27s - loss: 1.0277 - val_loss: 1.0759
#
# Epoch 00023: val_loss improved from 1.15350 to 1.07588, saving model to model.h5
# Epoch 24/100
# 141/141 - 27s - loss: 0.9505 - val_loss: 1.0026
#
# Epoch 00024: val_loss improved from 1.07588 to 1.00255, saving model to model.h5
# Epoch 25/100
# 141/141 - 27s - loss: 0.8806 - val_loss: 0.9519
#
# Epoch 00025: val_loss improved from 1.00255 to 0.95186, saving model to model.h5
# Epoch 26/100
# 141/141 - 27s - loss: 0.8151 - val_loss: 0.8955
#
# Epoch 00026: val_loss improved from 0.95186 to 0.89549, saving model to model.h5
# Epoch 27/100
# 141/141 - 27s - loss: 0.7530 - val_loss: 0.8449
#
# Epoch 00027: val_loss improved from 0.89549 to 0.84485, saving model to model.h5
# Epoch 28/100
# 141/141 - 27s - loss: 0.6945 - val_loss: 0.7972
#
# Epoch 00028: val_loss improved from 0.84485 to 0.79725, saving model to model.h5
# Epoch 29/100
# 141/141 - 27s - loss: 0.6389 - val_loss: 0.7505
#
# Epoch 00029: val_loss improved from 0.79725 to 0.75048, saving model to model.h5
# Epoch 30/100
# 141/141 - 27s - loss: 0.5895 - val_loss: 0.7130
#
# Epoch 00030: val_loss improved from 0.75048 to 0.71295, saving model to model.h5
# Epoch 31/100
# 141/141 - 27s - loss: 0.5438 - val_loss: 0.6740
#
# Epoch 00031: val_loss improved from 0.71295 to 0.67398, saving model to model.h5
# Epoch 32/100
# 141/141 - 27s - loss: 0.5010 - val_loss: 0.6392
#
# Epoch 00032: val_loss improved from 0.67398 to 0.63918, saving model to model.h5
# Epoch 33/100
# 141/141 - 27s - loss: 0.4623 - val_loss: 0.6072
#
# Epoch 00033: val_loss improved from 0.63918 to 0.60723, saving model to model.h5
# Epoch 34/100
# 141/141 - 27s - loss: 0.4262 - val_loss: 0.5806
#
# Epoch 00034: val_loss improved from 0.60723 to 0.58059, saving model to model.h5
# Epoch 35/100
# 141/141 - 27s - loss: 0.3956 - val_loss: 0.5625
#
# Epoch 00035: val_loss improved from 0.58059 to 0.56253, saving model to model.h5
# Epoch 36/100
# 141/141 - 27s - loss: 0.3653 - val_loss: 0.5354
#
# Epoch 00036: val_loss improved from 0.56253 to 0.53539, saving model to model.h5
# Epoch 37/100
# 141/141 - 27s - loss: 0.3392 - val_loss: 0.5186
#
# Epoch 00037: val_loss improved from 0.53539 to 0.51861, saving model to model.h5
# Epoch 38/100
# 141/141 - 27s - loss: 0.3152 - val_loss: 0.4950
#
# Epoch 00038: val_loss improved from 0.51861 to 0.49496, saving model to model.h5
# Epoch 39/100
# 141/141 - 28s - loss: 0.2915 - val_loss: 0.4843
#
# Epoch 00039: val_loss improved from 0.49496 to 0.48426, saving model to model.h5
# Epoch 40/100
# 141/141 - 27s - loss: 0.2716 - val_loss: 0.4625
#
# Epoch 00040: val_loss improved from 0.48426 to 0.46246, saving model to model.h5
# Epoch 41/100
# 141/141 - 27s - loss: 0.2528 - val_loss: 0.4539
#
# Epoch 00041: val_loss improved from 0.46246 to 0.45385, saving model to model.h5
# Epoch 42/100
# 141/141 - 27s - loss: 0.2361 - val_loss: 0.4397
#
# Epoch 00042: val_loss improved from 0.45385 to 0.43970, saving model to model.h5
# Epoch 43/100
# 141/141 - 27s - loss: 0.2211 - val_loss: 0.4311
#
# Epoch 00043: val_loss improved from 0.43970 to 0.43110, saving model to model.h5
# Epoch 44/100
# 141/141 - 27s - loss: 0.2079 - val_loss: 0.4224
#
# Epoch 00044: val_loss improved from 0.43110 to 0.42236, saving model to model.h5
# Epoch 45/100
# 141/141 - 27s - loss: 0.1963 - val_loss: 0.4134
#
# Epoch 00045: val_loss improved from 0.42236 to 0.41337, saving model to model.h5
# Epoch 46/100
# 141/141 - 27s - loss: 0.1856 - val_loss: 0.4069
#
# Epoch 00046: val_loss improved from 0.41337 to 0.40691, saving model to model.h5
# Epoch 47/100
# 141/141 - 27s - loss: 0.1748 - val_loss: 0.3997
#
# Epoch 00047: val_loss improved from 0.40691 to 0.39973, saving model to model.h5
# Epoch 48/100
# 141/141 - 27s - loss: 0.1645 - val_loss: 0.3926
#
# Epoch 00048: val_loss improved from 0.39973 to 0.39264, saving model to model.h5
# Epoch 49/100
# 141/141 - 27s - loss: 0.1561 - val_loss: 0.3926
#
# Epoch 00049: val_loss improved from 0.39264 to 0.39258, saving model to model.h5
# Epoch 50/100
# 141/141 - 27s - loss: 0.1514 - val_loss: 0.3816
#
# Epoch 00050: val_loss improved from 0.39258 to 0.38157, saving model to model.h5
# Epoch 51/100
# 141/141 - 27s - loss: 0.1453 - val_loss: 0.3820
#
# Epoch 00051: val_loss did not improve from 0.38157
# Epoch 52/100
# 141/141 - 27s - loss: 0.1410 - val_loss: 0.3803
#
# Epoch 00052: val_loss improved from 0.38157 to 0.38025, saving model to model.h5
# Epoch 53/100
# 141/141 - 27s - loss: 0.1352 - val_loss: 0.3751
#
# Epoch 00053: val_loss improved from 0.38025 to 0.37509, saving model to model.h5
# Epoch 54/100
# 141/141 - 27s - loss: 0.1292 - val_loss: 0.3721
#
# Epoch 00054: val_loss improved from 0.37509 to 0.37214, saving model to model.h5
# Epoch 55/100
# 141/141 - 27s - loss: 0.1245 - val_loss: 0.3694
#
# Epoch 00055: val_loss improved from 0.37214 to 0.36942, saving model to model.h5
# Epoch 56/100
# 141/141 - 27s - loss: 0.1211 - val_loss: 0.3691
#
# Epoch 00056: val_loss improved from 0.36942 to 0.36909, saving model to model.h5
# Epoch 57/100
# 141/141 - 27s - loss: 0.1186 - val_loss: 0.3675
#
# Epoch 00057: val_loss improved from 0.36909 to 0.36746, saving model to model.h5
# Epoch 58/100
# 141/141 - 27s - loss: 0.1155 - val_loss: 0.3685
#
# Epoch 00058: val_loss did not improve from 0.36746
# Epoch 59/100
# 141/141 - 27s - loss: 0.1119 - val_loss: 0.3618
#
# Epoch 00059: val_loss improved from 0.36746 to 0.36181, saving model to model.h5
# Epoch 60/100
# 141/141 - 27s - loss: 0.1089 - val_loss: 0.3604
#
# Epoch 00060: val_loss improved from 0.36181 to 0.36035, saving model to model.h5
# Epoch 61/100
# 141/141 - 27s - loss: 0.1069 - val_loss: 0.3614
#
# Epoch 00061: val_loss did not improve from 0.36035
# Epoch 62/100
# 141/141 - 28s - loss: 0.1035 - val_loss: 0.3601
#
# Epoch 00062: val_loss improved from 0.36035 to 0.36007, saving model to model.h5
# Epoch 63/100
# 141/141 - 27s - loss: 0.1027 - val_loss: 0.3626
#
# Epoch 00063: val_loss did not improve from 0.36007
# Epoch 64/100
# 141/141 - 27s - loss: 0.1012 - val_loss: 0.3611
#
# Epoch 00064: val_loss did not improve from 0.36007
# Epoch 65/100
# 141/141 - 27s - loss: 0.0992 - val_loss: 0.3559
#
# Epoch 00065: val_loss improved from 0.36007 to 0.35591, saving model to model.h5
# Epoch 66/100
# 141/141 - 27s - loss: 0.0971 - val_loss: 0.3565
#
# Epoch 00066: val_loss did not improve from 0.35591
# Epoch 67/100
# 141/141 - 27s - loss: 0.0964 - val_loss: 0.3573
#
# Epoch 00067: val_loss did not improve from 0.35591
# Epoch 68/100
# 141/141 - 27s - loss: 0.0945 - val_loss: 0.3579
#
# Epoch 00068: val_loss did not improve from 0.35591
# Epoch 69/100
# 141/141 - 27s - loss: 0.0931 - val_loss: 0.3577
#
# Epoch 00069: val_loss did not improve from 0.35591
# Epoch 70/100
# 141/141 - 27s - loss: 0.0930 - val_loss: 0.3595
#
# Epoch 00070: val_loss did not improve from 0.35591
# Epoch 71/100
# 141/141 - 27s - loss: 0.0926 - val_loss: 0.3608
#
# Epoch 00071: val_loss did not improve from 0.35591
# Epoch 72/100
# 141/141 - 27s - loss: 0.0918 - val_loss: 0.3581
#
# Epoch 00072: val_loss did not improve from 0.35591
# Epoch 73/100
# 141/141 - 27s - loss: 0.0908 - val_loss: 0.3585
#
# Epoch 00073: val_loss did not improve from 0.35591
# Epoch 74/100
# 141/141 - 27s - loss: 0.0909 - val_loss: 0.3599
#
# Epoch 00074: val_loss did not improve from 0.35591
# Epoch 75/100
# 141/141 - 27s - loss: 0.0909 - val_loss: 0.3613
#
# Epoch 00075: val_loss did not improve from 0.35591
# Epoch 76/100
# 141/141 - 27s - loss: 0.0891 - val_loss: 0.3611
#
# Epoch 00076: val_loss did not improve from 0.35591
# Epoch 77/100
# 141/141 - 27s - loss: 0.0886 - val_loss: 0.3641
#
# Epoch 00077: val_loss did not improve from 0.35591
# Epoch 78/100
# 141/141 - 27s - loss: 0.0890 - val_loss: 0.3599
#
# Epoch 00078: val_loss did not improve from 0.35591
# Epoch 79/100
# 141/141 - 27s - loss: 0.0855 - val_loss: 0.3590
#
# Epoch 00079: val_loss did not improve from 0.35591
# Epoch 80/100
# 141/141 - 27s - loss: 0.0835 - val_loss: 0.3596
#
# Epoch 00080: val_loss did not improve from 0.35591
# Epoch 81/100
# 141/141 - 27s - loss: 0.0838 - val_loss: 0.3580
#
# Epoch 00081: val_loss did not improve from 0.35591
# Epoch 82/100
# 141/141 - 27s - loss: 0.0823 - val_loss: 0.3597
#
# Epoch 00082: val_loss did not improve from 0.35591
# Epoch 83/100
# 141/141 - 27s - loss: 0.0830 - val_loss: 0.3575
#
# Epoch 00083: val_loss did not improve from 0.35591
# Epoch 84/100
# 141/141 - 28s - loss: 0.0817 - val_loss: 0.3596
#
# Epoch 00084: val_loss did not improve from 0.35591
# Epoch 85/100
# 141/141 - 27s - loss: 0.0811 - val_loss: 0.3601
#
# Epoch 00085: val_loss did not improve from 0.35591
# Epoch 86/100
# 141/141 - 27s - loss: 0.0801 - val_loss: 0.3589
#
# Epoch 00086: val_loss did not improve from 0.35591
# Epoch 87/100
# 141/141 - 27s - loss: 0.0795 - val_loss: 0.3600
#
# Epoch 00087: val_loss did not improve from 0.35591
# Epoch 88/100
# 141/141 - 27s - loss: 0.0803 - val_loss: 0.3585
#
# Epoch 00088: val_loss did not improve from 0.35591
# Epoch 89/100
# 141/141 - 27s - loss: 0.0786 - val_loss: 0.3597
#
# Epoch 00089: val_loss did not improve from 0.35591
# Epoch 90/100
# 141/141 - 27s - loss: 0.0786 - val_loss: 0.3597
#
# Epoch 00090: val_loss did not improve from 0.35591
# Epoch 91/100
# 141/141 - 27s - loss: 0.0784 - val_loss: 0.3614
#
# Epoch 00091: val_loss did not improve from 0.35591
# Epoch 92/100
# 141/141 - 27s - loss: 0.0785 - val_loss: 0.3627
#
# Epoch 00092: val_loss did not improve from 0.35591
# Epoch 93/100
# 141/141 - 27s - loss: 0.0795 - val_loss: 0.3602
#
# Epoch 00093: val_loss did not improve from 0.35591
# Epoch 94/100
# 141/141 - 27s - loss: 0.0785 - val_loss: 0.3594
#
# Epoch 00094: val_loss did not improve from 0.35591
# Epoch 95/100
# 141/141 - 27s - loss: 0.0779 - val_loss: 0.3621
#
# Epoch 00095: val_loss did not improve from 0.35591
# Epoch 96/100
# 141/141 - 27s - loss: 0.0775 - val_loss: 0.3644
#
# Epoch 00096: val_loss did not improve from 0.35591
# Epoch 97/100
# 141/141 - 27s - loss: 0.0775 - val_loss: 0.3633
#
# Epoch 00097: val_loss did not improve from 0.35591
# Epoch 98/100
# 141/141 - 27s - loss: 0.0767 - val_loss: 0.3624
#
# Epoch 00098: val_loss did not improve from 0.35591
# Epoch 99/100
# 141/141 - 27s - loss: 0.0766 - val_loss: 0.3658
#
# Epoch 00099: val_loss did not improve from 0.35591
# Epoch 100/100
# 141/141 - 27s - loss: 0.0767 - val_loss: 0.3629
#
# Epoch 00100: val_loss did not improve from 0.35591

# %%
from pickle import load
from numpy import array
from numpy import argmax
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import load_model
from nltk.translate.bleu_score import corpus_bleu

# load a clean dataset
def load_clean_sentences(filename):
	return load(open(filename, 'rb'))

# fit a tokenizer
def create_tokenizer(lines):
	tokenizer = Tokenizer()
	tokenizer.fit_on_texts(lines)
	return tokenizer

# max sentence length
def max_length(lines):
	return max(len(line.split()) for line in lines)

# encode and pad sequences
def encode_sequences(tokenizer, length, lines):
	# integer encode sequences
	X = tokenizer.texts_to_sequences(lines)
	# pad sequences with 0 values
	X = pad_sequences(X, maxlen=length, padding='post')
	return X

# map an integer to a word
def word_for_id(integer, tokenizer):
	for word, index in tokenizer.word_index.items():
		if index == integer:
			return word
	return None

# generate target given source sequence
def predict_sequence(model, tokenizer, source):
	prediction = model.predict(source, verbose=0)[0]
	integers = [argmax(vector) for vector in prediction]
	target = list()
	for i in integers:
		word = word_for_id(i, tokenizer)
		if word is None:
			break
		target.append(word)
	return ' '.join(target)

# evaluate the skill of the model
def evaluate_model(model, tokenizer, sources, raw_dataset):
	actual, predicted = list(), list()
	for i, source in enumerate(sources):
		# translate encoded source text
		source = source.reshape((1, source.shape[0]))
		translation = predict_sequence(model, eng_tokenizer, source)
		raw_target, raw_src,train = raw_dataset[i]
		if i < 10:
			print('src=[%s], target=[%s], predicted=[%s]' % (raw_src, raw_target, translation))
		actual.append([raw_target.split()])
		predicted.append(translation.split())
	# calculate BLEU score
	print('BLEU-1: %f' % corpus_bleu(actual, predicted, weights=(1.0, 0, 0, 0)))
	print('BLEU-2: %f' % corpus_bleu(actual, predicted, weights=(0.5, 0.5, 0, 0)))
	print('BLEU-3: %f' % corpus_bleu(actual, predicted, weights=(0.3, 0.3, 0.3, 0)))
	print('BLEU-4: %f' % corpus_bleu(actual, predicted, weights=(0.25, 0.25, 0.25, 0.25)))

# load datasets
dataset = load_clean_sentences('english-spanish-both.pkl')
train = load_clean_sentences('english-spanish-train.pkl')
test = load_clean_sentences('english-spanish-test.pkl')
# prepare english tokenizer
eng_tokenizer = create_tokenizer(dataset[:, 0])
eng_vocab_size = len(eng_tokenizer.word_index) + 1
eng_length = max_length(dataset[:, 0])
# prepare german tokenizer
ger_tokenizer = create_tokenizer(dataset[:, 1])
ger_vocab_size = len(ger_tokenizer.word_index) + 1
ger_length = max_length(dataset[:, 1])
# prepare data
trainX = encode_sequences(ger_tokenizer, ger_length, train[:, 1])
testX = encode_sequences(ger_tokenizer, ger_length, test[:, 1])

# load model
model = load_model('model.h5')
# test on some training sequences
print('train')
evaluate_model(model, eng_tokenizer, trainX, train)
# test on some test sequences
print('test')
evaluate_model(model, eng_tokenizer, testX, test)
# Out:
# train
# src=[se fuerte], target=[be brave], predicted=[be brave]
# src=[dejalo a tomas], target=[leave tom], predicted=[leave tom]
# src=[estuvo padre], target=[it was cool], predicted=[it was cool]
# src=[corri a refugiarme], target=[i ran for cover], predicted=[i ran for cover]
# src=[dejalo a tomas], target=[leave tom], predicted=[leave tom]
# src=[yo se frances], target=[i know french], predicted=[i know french]
# src=[quien viene], target=[whos coming], predicted=[who come]
# src=[corre vete a casa], target=[hurry home], predicted=[hurry home]
# src=[lo has hecho], target=[youve done it], predicted=[youve done it]
# src=[el fue a nara], target=[he went to nara], predicted=[he went to nara]
# BLEU-1: 0.955815
# BLEU-2: 0.938699
# BLEU-3: 0.868149
# BLEU-4: 0.579479
# test
# src=[tomas se fue de boston], target=[tom left boston], predicted=[tom left boston]
# src=[quien nado], target=[who swam], predicted=[who swam]
# src=[no tienes calor], target=[arent you hot], predicted=[arent you hot]
# src=[cedi], target=[i gave up], predicted=[i gave up]
# src=[deten ese coche], target=[stop that car], predicted=[stop that car]
# src=[usted ayudo], target=[did you help], predicted=[did you help]
# src=[usted tiene vino], target=[you have wine], predicted=[you have wine]
# src=[por favor arreglalo], target=[please fix it], predicted=[please fix it]
# src=[es una gran ciudad], target=[its a big city], predicted=[its a big city]
# src=[tom guino el ojo], target=[tom winked], predicted=[tom winked]
# BLEU-1: 0.907684
# BLEU-2: 0.880611
# BLEU-3: 0.813615
# BLEU-4: 0.537467
